# %%
import pandas as pd

# %% [markdown]
# # 2 Main Datatypes i)Series ii)DataFrame
# # Series is 1-Dimensional coloum
# # DataFrame is 2 - Dimensional many coloums represent
# # Importing and Exporting CSV using Pands

# %%
#2 Main datatypes
series = pd.Series(["BMW","Toyota","Honda"])

# %%
#series is a  1-dimesional 
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colours = pd.Series(["red","Yellow","Orange"])
colours
# Out:
# 0       red
# 1    Yellow
# 2    Orange
# dtype: object

# %%
#DataFrame is a 2-dimensional
car_data = pd.DataFrame({"carmake":series,"colour":colours})
car_data
# Out:
#   carmake  colour
# 0     BMW     red
# 1  Toyota  Yellow
# 2   Honda  Orange

# %%
#import data in pands
car_sales = pd.read_csv("car_sales_data.csv")
car_sales
# Out:
#    Car_ID     Brand     Model  Year  Price_INR Fuel_Type
# 0       1    Toyota   Corolla  2020     900000    Petrol
# 1       2     Honda     Civic  2019     850000    Petrol
# 2       3   Hyundai       i20  2021     750000    Diesel
# 3       4    Maruti     Swift  2018     600000    Petrol
# 4       5       Kia    Seltos  2022    1200000    Diesel
# 5       6      Tata     Nexon  2021     800000    Petrol
# 6       7  Mahindra    XUV300  2020     950000    Diesel
# 7       8      Ford  EcoSport  2019     700000    Petrol
# 8       9       BMW        X1  2022    3500000    Diesel
# 9      10      Audi        A4  2021    4200000    Petrol

# %%
#Exporting a dataframe
car_sales.to_csv("exported-car_sales_data.csv",index=False)

# %%
exported_car_sales = pd.read_csv("exported-car_sales_data.csv")
exported_car_sales
# Out:
#    Car_ID     Brand     Model  Year  Price_INR Fuel_Type
# 0       1    Toyota   Corolla  2020     900000    Petrol
# 1       2     Honda     Civic  2019     850000    Petrol
# 2       3   Hyundai       i20  2021     750000    Diesel
# 3       4    Maruti     Swift  2018     600000    Petrol
# 4       5       Kia    Seltos  2022    1200000    Diesel
# 5       6      Tata     Nexon  2021     800000    Petrol
# 6       7  Mahindra    XUV300  2020     950000    Diesel
# 7       8      Ford  EcoSport  2019     700000    Petrol
# 8       9       BMW        X1  2022    3500000    Diesel
# 9      10      Audi        A4  2021    4200000    Petrol

# %% [markdown]
# ## Describe Data

# %%
#Attribute does't have ()
car_sales.dtypes

# Funcation have ()
#car_sales.to.csv()
# Out:
# Car_ID        int64
# Brand        object
# Model        object
# Year          int64
# Price_INR     int64
# Fuel_Type    object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Car_ID', 'Brand', 'Model', 'Year', 'Price_INR', 'Fuel_Type'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#          Car_ID         Year     Price_INR
# count  10.00000    10.000000  1.000000e+01
# mean    5.50000  2020.300000  1.445000e+06
# std     3.02765     1.337494  1.288291e+06
# min     1.00000  2018.000000  6.000000e+05
# 25%     3.25000  2019.250000  7.625000e+05
# 50%     5.50000  2020.500000  8.750000e+05
# 75%     7.75000  2021.000000  1.137500e+06
# max    10.00000  2022.000000  4.200000e+06

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Car_ID     10 non-null     int64
#  1   Brand      10 non-null     object
#  2   Model      10 non-null     object
#  3   Year       10 non-null     int64
#  4   Price_INR  10 non-null     int64
#  5   Fuel_Type  10 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 612.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Car_ID             5.5
# Year            2020.3
# Price_INR    1445000.0
# dtype: float64

# %%
car_sales["Price_INR"].sum()
# Out:
# np.int64(14450000)

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#    Car_ID    Brand    Model  Year  Price_INR Fuel_Type
# 0       1   Toyota  Corolla  2020     900000    Petrol
# 1       2    Honda    Civic  2019     850000    Petrol
# 2       3  Hyundai      i20  2021     750000    Diesel
# 3       4   Maruti    Swift  2018     600000    Petrol
# 4       5      Kia   Seltos  2022    1200000    Diesel

# %%
car_sales.tail(2)
# Out:
#    Car_ID Brand Model  Year  Price_INR Fuel_Type
# 8       9   BMW    X1  2022    3500000    Diesel
# 9      10  Audi    A4  2021    4200000    Petrol

# %%
#.loc and .iloc
animals = pd.Series(["cat", "dog" , "bird" , "panda" , "snake"],index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
#loc = refer to index and location
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
#.iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.loc[:3]
# Out:
#    Car_ID    Brand    Model  Year  Price_INR Fuel_Type
# 0       1   Toyota  Corolla  2020     900000    Petrol
# 1       2    Honda    Civic  2019     850000    Petrol
# 2       3  Hyundai      i20  2021     750000    Diesel
# 3       4   Maruti    Swift  2018     600000    Petrol

# %%
car_sales.Brand
# Out:
# 0      Toyota
# 1       Honda
# 2     Hyundai
# 3      Maruti
# 4         Kia
# 5        Tata
# 6    Mahindra
# 7        Ford
# 8         BMW
# 9        Audi
# Name: Brand, dtype: object

# %%
#Filitering
car_sales[car_sales["Brand"]=="Toyota"]
# Out:
#    Car_ID   Brand    Model  Year  Price_INR Fuel_Type
# 0       1  Toyota  Corolla  2020     900000    Petrol

# %%
pd.crosstab(car_sales["Brand"],car_sales["Price_INR"])
# Out:
# Price_INR  600000   700000   750000   800000   850000   900000   950000   \
# Brand
# Audi             0        0        0        0        0        0        0
# BMW              0        0        0        0        0        0        0
# Ford             0        1        0        0        0        0        0
# Honda            0        0        0        0        1        0        0
# Hyundai          0        0        1        0        0        0        0
# Kia              0        0        0        0        0        0        0
# Mahindra         0        0        0        0        0        0        1
# Maruti           1        0        0        0        0        0        0
# Tata             0        0        0        1        0        0        0
# Toyota           0        0        0        0        0        1        0
#
# Price_INR  1200000  3500000  4200000
# Brand
# Audi             0        0        1
# BMW              0        1        0
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Price_INR"].plot()
# Out:
# <Axes: >

# %%
car_sales["Price_INR"].hist()
# Out:
# <Axes: >
