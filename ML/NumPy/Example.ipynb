# %% [markdown]
# ## Dot Product Exmple
#
# Student marks

# %%
import numpy as np

# %%
np.random.seed(0)
student_marks = np.random.randint(100,size = (4,6))
student_marks
# Out:
# array([[44, 47, 64, 67, 67,  9],
#        [83, 21, 36, 87, 70, 88],
#        [88, 12, 58, 65, 39, 87],
#        [46, 88, 81, 37, 25, 77]], dtype=int32)

# %%
student = np.DataFrame(student_marks , index =["Jhon", "Alex", "Joy", "Robb"], colums=["Maths", "Scinece", "Biology", "Physices", "Computer Scinece", "Chemistry"])
student
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 student = np.DataFrame(student_marks , index =["Jhon", "Alex", "Joy", "Robb"], colums=["Maths", "Scinece", "Biology", "Physices", "Computer Scinece", "Chemistry"])
#       2 student
#
# File ~\Desktop\SimpleC\env\Lib\site-packages\numpy\__init__.py:795, in __getattr__(attr)
#     792     import numpy.char as char
#     793     return char.chararray
# --> 795 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'DataFrame'

# %%
import pandas as pd

# %%
student = pd.DataFrame(student_marks , index =["Jhon", "Alex", "Joy", "Robb"], columns=["Maths", "Scinece", "Biology", "Physices", "Computer Scinece", "Chemistry"])
student
# Out:
#       Maths  Scinece  Biology  Physices  Computer Scinece  Chemistry
# Jhon     44       47       64        67                67          9
# Alex     83       21       36        87                70         88
# Joy      88       12       58        65                39         87
# Robb     46       88       81        37                25         77
